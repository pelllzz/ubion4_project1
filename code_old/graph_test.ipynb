# %%
import pandas as pd
import matplotlib.pyplot as plt

test = pd.read_excel("../raw_data/K-MBS_real.xlsx").drop(columns=['Unnamed: 0'])
test
# Out:
#                 발행회차       발행일자        기준월        초기대출잔액        당월대출잔액  \
# 0     KHFCMB2022S-13 2022-06-28 2022-06-01  839656363820  835571331825
# 1     KHFCMB2022S-12 2022-06-21 2022-06-01  505593664980  500416724300
# 2     KHFCMB2022S-11 2022-06-10 2022-06-01  819947731214  813869394514
# 3     KHFCMB2022S-10 2022-05-24 2022-06-01  839030015758  830735646646
# 4     KHFCMB2022S-10 2022-05-24 2022-05-01  839030015758  834998788212
# ...              ...        ...        ...           ...           ...
# 4033  KHFCMB2005S-02 2005-03-23 2021-12-01  409788116860    2373900953
# 4034  KHFCMB2005S-02 2005-03-23 2021-11-01  409788116860    2397128565
# 4035  KHFCMB2005S-02 2005-03-23 2021-10-01  409788116860    2427184607
# 4036  KHFCMB2005S-02 2005-03-23 2021-09-01  409788116860    2477908493
# 4037  KHFCMB2005S-02 2005-03-23 2021-08-01  409788116860    2530788512
#
#       평균 LTV  평균 DTI   조기상환율      연체율
# 0      58.81   27.63  0.2359   0.0000
# ...

# %%
test2 = pd.read_excel("../raw_data/K-MBS_real2.xlsx")
test2
# Out:
#      Loading ...           Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0            NaN                  NaN        NaN        NaN        NaN
# 1            NaN                  NaN        NaN     국고채 금리        NaN
# 2           발행회차                 발행일자       가중평균        NaN        NaN
# 3            NaN                  NaN       발행금리        NaN        NaN
# 4            NaN                  NaN        NaN         1년         3년
# ..           ...                  ...        ...        ...        ...
# 350  MBS 2011-05  2011-04-26 00:00:00       3.71          0          0
# 351  MBS 2011-04  2011-04-13 00:00:00        4.5          0          0
# 352  MBS 2011-03  2011-03-29 00:00:00       4.48          0          0
# 353  MBS 2011-02  2011-02-17 00:00:00       4.78          0          0
# 354  MBS 2011-01  2011-01-28 00:00:00       4.76          0          0
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          NaN        NaN        NaN        NaN
# ...

# %%
import numpy as np

plt.figure(figsize=(64,8))
plt.plot(test['발행일자'], test['조기상환율'], linestyle='-')
#plt.plot(test['발행일자'], test2['Unnamed:3'][6:])
plt.show()

# %%
plt.figure(figsize=(32,8))
plt.plot(test2['Unnamed: 3'][6:])
plt.show()

# %%
test['조기상환율']
# Out:
# 0       0.2359
# 1       0.2903
# 2       0.2994
# 3       0.3491
# 4       0.2421
#          ...
# 4033    0.4491
# 4034    0.9494
# 4035    2.7106
# 4036    2.7021
# 4037    0.2164
# Name: 조기상환율, Length: 4038, dtype: float64
